# %% [markdown]
# 본격적인 모델링에 들어가기 앞서, data_ocr/training 폴더에 ipynb_checkpoints 파일이 있으면 에러가 발생
#
# 에러 방지를 위해 폴더 제거

# %%
import os
os.path.isdir('./data_ocr/training/.ipynb_checkpoints')
os.rmdir('./data_ocr/validation/.ipynb_checkpoints')

# %% [markdown]
# ## 메인 모델링

# %%
# !git clone https://github.com/clovaai/deep-text-recognition-benchmark.git

# %% [markdown]
# 깃허브 코드 Clone 이후 train.py 파일 285번 줄의 opt.character 인자를
#
# ```python
# " !\"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\\]^_`abcdefghijklmnopqrstuvwxyz{|}~가각간갇갈감갑값강갖같갚갛개객걀거걱건걷걸검겁것겉게겨격겪견결겹경곁계고곡곤곧골곰곱곳공과관광괜괴굉교구국군굳굴굵굶굽궁권귀규균그극근글긁금급긋긍기긴길김깅깊까깎깐깔깜깝깥깨꺼꺾껍껏껑께껴꼬꼭꼴꼼꼽꽂꽃꽉꽤꾸꿀꿈뀌끄끈끊끌끓끔끗끝끼낌나낙낚난날낡남납낫낭낮낯낱낳내냄냉냐냥너넉널넓넘넣네넥넷녀녁년념녕노녹논놀놈농높놓놔뇌뇨누눈눕뉘뉴늄느늑는늘늙능늦늬니닐님다닥닦단닫달닭닮담답닷당닿대댁댐더덕던덜덤덥덧덩덮데델도독돈돌돕동돼되된두둑둘둠둡둥뒤뒷드득든듣들듬듭듯등디딩딪따딱딴딸땀땅때땜떠떡떤떨떻떼또똑뚜뚫뚱뛰뜨뜩뜯뜰뜻띄라락란람랍랑랗래랜램랫략량러럭런럴럼럽럿렁렇레렉렌려력련렬렵령례로록론롬롭롯료루룩룹룻뤄류륙률륭르른름릇릎리릭린림립릿마막만많말맑맘맙맛망맞맡맣매맥맨맵맺머먹먼멀멈멋멍멎메멘멩며면멸명몇모목몰몸몹못몽묘무묵묶문묻물뭄뭇뭐뭣므미민믿밀밉밌및밑바박밖반받발밝밟밤밥방밭배백뱀뱃뱉버번벌범법벗베벤벼벽변별볍병볕보복볶본볼봄봇봉뵈뵙부북분불붉붐붓붕붙뷰브블비빌빗빚빛빠빨빵빼뺨뻐뻔뻗뼈뽑뿌뿐쁘쁨사삭산살삶삼상새색샌생서석섞선설섬섭섯성세센셈셋션소속손솔솜솟송솥쇄쇠쇼수숙순술숨숫숲쉬쉽슈스슨슬슴습슷승시식신싣실싫심십싱싶싸싹쌀쌍쌓써썩썰썹쎄쏘쏟쑤쓰쓸씀씌씨씩씬씹씻아악안앉않알앓암압앗앙앞애액야약얇양얗얘어억언얹얻얼엄업없엇엉엌엎에엔엘여역연열엷염엽엿영옆예옛오옥온올옮옳옷와완왕왜왠외왼요욕용우욱운울움웃웅워원월웨웬위윗유육율으윽은을음응의이익인일읽잃임입잇있잊잎자작잔잖잘잠잡장잦재쟁저적전절젊점접젓정젖제젠젯져조족존졸좀좁종좋좌죄주죽준줄줌줍중쥐즈즉즌즐즘증지직진질짐집짓징짙짚짜짝짧째쨌쩌쩍쩐쪽쫓쭈쭉찌찍찢차착찬찮찰참창찾채책챔챙처척천철첫청체쳐초촉촌총촬최추축춘출춤춥춧충취츠측츰층치칙친칠침칭카칸칼캐캠커컨컬컴컵컷켓켜코콜콤콩쾌쿠퀴크큰클큼키킬타탁탄탈탑탓탕태택탤터턱털텅테텍텔템토톤톱통퇴투툼퉁튀튜트특튼튿틀틈티틱팀팅파팎판팔패팩팬퍼퍽페펴편펼평폐포폭표푸푹풀품풍퓨프플픔피픽필핏핑하학한할함합항해핵핸햄햇행향허헌험헤헬혀현혈협형혜호혹혼홀홍화확환활황회획횟효후훈훌훔훨휘휴흉흐흑흔흘흙흡흥흩희흰히힘"
# ```
# 으로 수정.
#
# 교원그룹 유아손글씨 데이터엔 특수문자, 공백, 숫자, 영어가 없지만 EasyOCR에서 한국어로 사전학습한 모델은 위 글자들을 모두 포함하여 학습시켰기 때문에, 우리도 사용

# %%
# %cd deep-text-recognition-benchmark

! python3 train.py \
        --train_data './data_ocr/training' \
        --valid_data './data_ocr/validation' \
        --select_data / \
        --batch_ratio 1 \
        --Transformation TPS \
        --FeatureExtraction "VGG" \
        --SequenceModeling "BiLSTM" \
        --Prediction "CTC" \
        --input_channel 1 \
        --output_channel 256 \
        --hidden_size 256 \
        --saved_model pretrained_model/korean_g2.pth \
        --FT
# Out:
# /home/cuai5th/CUAI_2022/KWAKsumin/OCR/deep-text-recognition-benchmark
# ------ Use multi-GPU setting ------
# if you stuck too long time with multi-GPU setting, try to set --workers 0
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: ./data_ocr/training
# opt.select_data: ['/']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    ./data_ocr/training	 dataset: /
# sub-directory:	/kordata	 num samples: 53728
# num total samples of /: 53728 x 1.0 (total_data_usage_ratio) = 53728
# num samples of / per batch: 384 x 1.0 (batch_ratio) = 384
# --------------------------------------------------------------------------------
# Total_batch_size: 384 = 384
# --------------------------------------------------------------------------------
# dataset_root:    ./data_ocr/validation	 dataset: /
# sub-directory:	/kordata	 num samples: 13487
# --------------------------------------------------------------------------------
# model input parameters 32 100 20 1 256 256 1009 25 TPS VGG BiLSTM CTC
# loading pretrained model from pretrained_model/korean_g2.pth
# Model:
# DataParallel(
#   (module): Model(
#     (FeatureExtraction): VGG_FeatureExtractor(
#       (ConvNet): Sequential(
#         (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): ReLU(inplace=True)
#         (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (7): ReLU(inplace=True)
#         (8): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (9): ReLU(inplace=True)
#         (10): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (11): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (16): ReLU(inplace=True)
#         (17): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (18): Conv2d(256, 256, kernel_size=(2, 2), stride=(1, 1))
#         (19): ReLU(inplace=True)
#       )
#     )
#     (AdaptiveAvgPool): AdaptiveAvgPool2d(output_size=(None, 1))
#     (SequenceModeling): Sequential(
#       (0): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#       (1): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#     )
#     (Prediction): Linear(in_features=256, out_features=1009, bias=True)
#   )
# )
# Trainable params num :  4015729
# Optimizer:
# Adadelta (
# Parameter Group 0
#     eps: 1e-08
#     lr: 1
#     rho: 0.95
#     weight_decay: 0
# )
# ------------ Options -------------
# exp_name: TPS-VGG-BiLSTM-CTC-Seed1111
# train_data: ./data_ocr/training
# valid_data: ./data_ocr/validation
# manualSeed: 1111
# workers: 8
# batch_size: 384
# num_iter: 300000
# valInterval: 2000
# saved_model: pretrained_model/korean_g2.pth
# FT: True
# adam: False
# lr: 1
# beta1: 0.9
# rho: 0.95
# eps: 1e-08
# grad_clip: 5
# baiduCTC: False
# select_data: ['/']
# batch_ratio: ['1']
# total_data_usage_ratio: 1.0
# batch_max_length: 25
# imgH: 32
# imgW: 100
# rgb: False
# character:  !"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\]^_`abcdefghijklmnopqrstuvwxyz{|}~가각간갇갈감갑값강갖같갚갛개객걀거걱건걷걸검겁것겉게겨격겪견결겹경곁계고곡곤곧골곰곱곳공과관광괜괴굉교구국군굳굴굵굶굽궁권귀규균그극근글긁금급긋긍기긴길김깅깊까깎깐깔깜깝깥깨꺼꺾껍껏껑께껴꼬꼭꼴꼼꼽꽂꽃꽉꽤꾸꿀꿈뀌끄끈끊끌끓끔끗끝끼낌나낙낚난날낡남납낫낭낮낯낱낳내냄냉냐냥너넉널넓넘넣네넥넷녀녁년념녕노녹논놀놈농높놓놔뇌뇨누눈눕뉘뉴늄느늑는늘늙능늦늬니닐님다닥닦단닫달닭닮담답닷당닿대댁댐더덕던덜덤덥덧덩덮데델도독돈돌돕동돼되된두둑둘둠둡둥뒤뒷드득든듣들듬듭듯등디딩딪따딱딴딸땀땅때땜떠떡떤떨떻떼또똑뚜뚫뚱뛰뜨뜩뜯뜰뜻띄라락란람랍랑랗래랜램랫략량러럭런럴럼럽럿렁렇레렉렌려력련렬렵령례로록론롬롭롯료루룩룹룻뤄류륙률륭르른름릇릎리릭린림립릿마막만많말맑맘맙맛망맞맡맣매맥맨맵맺머먹먼멀멈멋멍멎메멘멩며면멸명몇모목몰몸몹못몽묘무묵묶문묻물뭄뭇뭐뭣므미민믿밀밉밌및밑바박밖반받발밝밟밤밥방밭배백뱀뱃뱉버번벌범법벗베벤벼벽변별볍병볕보복볶본볼봄봇봉뵈뵙부북분불붉붐붓붕붙뷰브블비빌빗빚빛빠빨빵빼뺨뻐뻔뻗뼈뽑뿌뿐쁘쁨사삭산살삶삼상새색샌생서석섞선설섬섭섯성세센셈셋션소속손솔솜솟송솥쇄쇠쇼수숙순술숨숫숲쉬쉽슈스슨슬슴습슷승시식신싣실싫심십싱싶싸싹쌀쌍쌓써썩썰썹쎄쏘쏟쑤쓰쓸씀씌씨씩씬씹씻아악안앉않알앓암압앗앙앞애액야약얇양얗얘어억언얹얻얼엄업없엇엉엌엎에엔엘여역연열엷염엽엿영옆예옛오옥온올옮옳옷와완왕왜왠외왼요욕용우욱운울움웃웅워원월웨웬위윗유육율으윽은을음응의이익인일읽잃임입잇있잊잎자작잔잖잘잠잡장잦재쟁저적전절젊점접젓정젖제젠젯져조족존졸좀좁종좋좌죄주죽준줄줌줍중쥐즈즉즌즐즘증지직진질짐집짓징짙짚짜짝짧째쨌쩌쩍쩐쪽쫓쭈쭉찌찍찢차착찬찮찰참창찾채책챔챙처척천철첫청체쳐초촉촌총촬최추축춘출춤춥춧충취츠측츰층치칙친칠침칭카칸칼캐캠커컨컬컴컵컷켓켜코콜콤콩쾌쿠퀴크큰클큼키킬타탁탄탈탑탓탕태택탤터턱털텅테텍텔템토톤톱통퇴투툼퉁튀튜트특튼튿틀틈티틱팀팅파팎판팔패팩팬퍼퍽페펴편펼평폐포폭표푸푹풀품풍퓨프플픔피픽필핏핑하학한할함합항해핵핸햄햇행향허헌험헤헬혀현혈협형혜호혹혼홀홍화확환활황회획횟효후훈훌훔훨휘휴흉흐흑흔흘흙흡흥흩희흰히힘
# sensitive: False
# PAD: False
# data_filtering_off: False
# Transformation: TPS
# FeatureExtraction: VGG
# SequenceModeling: BiLSTM
# Prediction: CTC
# num_fiducial: 20
# input_channel: 1
# output_channel: 256
# hidden_size: 256
# num_gpu: 2
# num_class: 1009
# ---------------------------------------
#
# [1/300000] Train loss: 4.33150, Valid loss: 3.41998, Elapsed_time: 12.19255
# Current_accuracy : 42.560, Current_norm_ED  : 0.55
# Best_accuracy    : 42.560, Best_norm_ED     : 0.55
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 정치권                       | 점조권                       | 0.2233	False
# 스승                        | 스승                        | 0.9988	True
# 이르다                       | 이르다                       | 0.8884	True
# 파괴하다                      | 파괴하다                      | 0.6357	True
# 감사하다                      | 잠사하다                      | 0.1561	False
# --------------------------------------------------------------------------------
# [2000/300000] Train loss: 0.16055, Valid loss: 0.23811, Elapsed_time: 314.00148
# Current_accuracy : 90.672, Current_norm_ED  : 0.94
# Best_accuracy    : 90.672, Best_norm_ED     : 0.94
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 국                         | 국                         | 0.9998	True
# 전달하다                      | 전달하다                      | 0.9357	True
# 이월                        | 이월                        | 0.9998	True
# 떠오르다                      | 떠오르다                      | 0.9854	True
# 분                         | 분                         | 0.9997	True
# --------------------------------------------------------------------------------
# [4000/300000] Train loss: 0.00193, Valid loss: 0.23095, Elapsed_time: 615.75536
# Current_accuracy : 91.258, Current_norm_ED  : 0.95
# Best_accuracy    : 91.258, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 튀기다                       | 튀기다                       | 0.9994	True
# 창가                        | 창가                        | 0.9996	True
# 여행사                       | 여행사                       | 0.9111	True
# 틀림없이                      | 틀림없이                      | 0.9990	True
# 얘                         | 얘                         | 0.9931	True
# --------------------------------------------------------------------------------
# [6000/300000] Train loss: 0.00061, Valid loss: 0.23404, Elapsed_time: 920.58647
# Current_accuracy : 91.510, Current_norm_ED  : 0.95
# Best_accuracy    : 91.510, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 학교생활                      | 학교생활                      | 0.9960	True
# 그대                        | 그대                        | 0.9996	True
# 마                         | 마                         | 1.0000	True
# 리                         | 리                         | 1.0000	True
# 허리                        | 허리                        | 0.8979	True
# --------------------------------------------------------------------------------
# [8000/300000] Train loss: 0.00032, Valid loss: 0.23649, Elapsed_time: 1220.49074
# Current_accuracy : 91.711, Current_norm_ED  : 0.95
# Best_accuracy    : 91.711, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 아유                        | 아무                        | 0.9673	False
# 되풀이되다                     | 되풀이되다                     | 0.9999	True
# 예방하다                      | 예방하다                      | 0.9990	True
# 매년                        | 매년                        | 0.9981	True
# 행하다                       | 행하다                       | 0.9987	True
# --------------------------------------------------------------------------------
# [10000/300000] Train loss: 0.00023, Valid loss: 0.24682, Elapsed_time: 1521.49967
# Current_accuracy : 91.688, Current_norm_ED  : 0.95
# Best_accuracy    : 91.711, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 복사                        | 복사                        | 0.9892	True
# 모두                        | 모두                        | 0.9665	True
# 묵다                        | 묵다                        | 0.9875	True
# 한편                        | 한편                        | 0.9998	True
# 전부                        | 전부                        | 0.9953	True
# --------------------------------------------------------------------------------
# [12000/300000] Train loss: 0.00018, Valid loss: 0.24432, Elapsed_time: 1825.12151
# Current_accuracy : 91.777, Current_norm_ED  : 0.95
# Best_accuracy    : 91.777, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 올라서다                      | 밀나새다                      | 0.3318	False
# 대학원                       | 대학원                       | 1.0000	True
# 몇십                        | 몇심                        | 0.7596	False
# 다                         | 다                         | 0.9997	True
# 하나                        | 하나                        | 1.0000	True
# --------------------------------------------------------------------------------
# [14000/300000] Train loss: 0.00014, Valid loss: 0.23909, Elapsed_time: 2127.54013
# Current_accuracy : 91.770, Current_norm_ED  : 0.95
# Best_accuracy    : 91.777, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 땀                         | 떻                         | 0.7479	False
# 역                         | 역                         | 1.0000	True
# 과자                        | 과자                        | 0.9998	True
# 양념                        | 양녕                        | 0.9715	False
# 히                         | 히                         | 0.9993	True
# --------------------------------------------------------------------------------
# [16000/300000] Train loss: 0.00012, Valid loss: 0.24251, Elapsed_time: 2427.46241
# Current_accuracy : 91.829, Current_norm_ED  : 0.95
# Best_accuracy    : 91.829, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 간장                        | 간장                        | 0.9999	True
# 있                         | 있                         | 0.9932	True
# 진리                        | 진리                        | 0.9998	True
# 빨리                        | 빨리                        | 0.9996	True
# 쉽                         | 쉽                         | 0.9994	True
# --------------------------------------------------------------------------------
# [18000/300000] Train loss: 0.00011, Valid loss: 0.24013, Elapsed_time: 2727.46733
# Current_accuracy : 91.837, Current_norm_ED  : 0.95
# Best_accuracy    : 91.837, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 더                         | 더                         | 0.9986	True
# 파                         | 파                         | 0.6950	True
# 내                         | 내                         | 1.0000	True
# 무지개                       | 무지개                       | 0.9908	True
# 예약                        | 예약                        | 0.9971	True
# --------------------------------------------------------------------------------
# [20000/300000] Train loss: 0.00010, Valid loss: 0.24566, Elapsed_time: 3029.23370
# Current_accuracy : 91.918, Current_norm_ED  : 0.95
# Best_accuracy    : 91.918, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 버스                        | 버스                        | 0.9997	True
# 하긴                        | 하긴                        | 0.9999	True
# 실감                        | 실감                        | 0.9999	True
# 노동                        | 노동                        | 1.0000	True
# 나빠지다                      | 나빠지다                      | 0.9993	True
# --------------------------------------------------------------------------------
# [22000/300000] Train loss: 0.00009, Valid loss: 0.24996, Elapsed_time: 3337.66592
# Current_accuracy : 91.896, Current_norm_ED  : 0.95
# Best_accuracy    : 91.918, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 품목                        | 품목                        | 0.9995	True
# 원                         | 원                         | 0.9999	True
# 덜                         | 덜                         | 1.0000	True
# 물론                        | 물론                        | 0.9999	True
# 해                         | 해                         | 0.9999	True
# --------------------------------------------------------------------------------
# [24000/300000] Train loss: 0.00008, Valid loss: 0.24054, Elapsed_time: 3636.68312
# Current_accuracy : 91.911, Current_norm_ED  : 0.95
# Best_accuracy    : 91.918, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 분명해지다                     | 분명해지다                     | 0.9464	True
# 테러                        | 테러                        | 1.0000	True
# 유발하다                      | 유발하다                      | 0.9995	True
# 모퉁이                       | 모퉁이                       | 0.9999	True
# 급격히                       | 급격히                       | 0.9997	True
# --------------------------------------------------------------------------------
# [26000/300000] Train loss: 0.00007, Valid loss: 0.24857, Elapsed_time: 3936.19193
# Current_accuracy : 91.963, Current_norm_ED  : 0.95
# Best_accuracy    : 91.963, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 합하다                       | 합하다                       | 0.9995	True
# 잦다                        | 잦다                        | 0.9998	True
# 마크                        | 마크                        | 0.9999	True
# 토론                        | 토론                        | 0.9995	True
# 블                         | 블                         | 0.6879	True
# --------------------------------------------------------------------------------
# [28000/300000] Train loss: 0.00006, Valid loss: 0.24129, Elapsed_time: 4235.65173
# Current_accuracy : 91.933, Current_norm_ED  : 0.95
# Best_accuracy    : 91.963, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 향                         | 향                         | 0.9648	True
# 소용없다                      | 소용없다                      | 0.9943	True
# 강의하다                      | 강의하다                      | 0.9890	True
# 장                         | 장                         | 1.0000	True
# 엔                         | 엔                         | 0.9999	True
# --------------------------------------------------------------------------------
# [30000/300000] Train loss: 0.00006, Valid loss: 0.24793, Elapsed_time: 4539.85898
# Current_accuracy : 91.992, Current_norm_ED  : 0.95
# Best_accuracy    : 91.992, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 회관                        | 회관                        | 0.9995	True
# 되다                        | 되다                        | 0.9997	True
# 조미료                       | 조미료                       | 1.0000	True
# 대학교                       | 대학교                       | 0.9992	True
# 역할                        | 역할                        | 0.9989	True
# --------------------------------------------------------------------------------
# [32000/300000] Train loss: 0.00005, Valid loss: 0.24632, Elapsed_time: 4844.95486
# Current_accuracy : 91.992, Current_norm_ED  : 0.95
# Best_accuracy    : 91.992, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 아파트                       | 아라트                       | 0.9914	False
# 팬                         | 팬                         | 0.9988	True
# 초반                        | 초반                        | 0.9980	True
# 싹                         | 싹                         | 1.0000	True
# 연구                        | 연구                        | 0.9946	True
# --------------------------------------------------------------------------------
# [34000/300000] Train loss: 0.00005, Valid loss: 0.25831, Elapsed_time: 5146.14662
# Current_accuracy : 91.992, Current_norm_ED  : 0.95
# Best_accuracy    : 91.992, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 머리말                       | 머리말                       | 1.0000	True
# 원인                        | 원인                        | 0.9999	True
# 절                         | 절                         | 0.9999	True
# 학년                        | 학년                        | 0.9991	True
# 견해                        | 견해                        | 0.9715	True
# --------------------------------------------------------------------------------
# [36000/300000] Train loss: 0.00005, Valid loss: 0.24913, Elapsed_time: 5451.31300
# Current_accuracy : 92.066, Current_norm_ED  : 0.95
# Best_accuracy    : 92.066, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 동포                        | 동포                        | 0.6536	True
# 햄버거                       | 햄버거                       | 0.9987	True
# 알                         | 알                         | 0.9879	True
# 성                         | 정                         | 0.9075	False
# 엇갈리다                      | 엇갈리다                      | 0.9991	True
# --------------------------------------------------------------------------------
# [38000/300000] Train loss: 0.00005, Valid loss: 0.24936, Elapsed_time: 5752.37834
# Current_accuracy : 92.052, Current_norm_ED  : 0.95
# Best_accuracy    : 92.066, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 중심                        | 중심                        | 0.8778	True
# 안녕하다                      | 안녕하다                      | 0.9948	True
# 박                         | 박                         | 1.0000	True
# 감기                        | 감기                        | 1.0000	True
# 켜다                        | 켜다                        | 0.6268	True
# --------------------------------------------------------------------------------
# [40000/300000] Train loss: 0.00004, Valid loss: 0.24261, Elapsed_time: 6048.22830
# Current_accuracy : 92.096, Current_norm_ED  : 0.95
# Best_accuracy    : 92.096, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 사자                        | 사자                        | 0.9935	True
# 마흔                        | 마흔                        | 0.9997	True
# 나물                        | 나물                        | 0.9996	True
# 대중교통                      | 대중교통                      | 0.9976	True
# 첫                         | 첫                         | 1.0000	True
# --------------------------------------------------------------------------------
# [42000/300000] Train loss: 0.00004, Valid loss: 0.24660, Elapsed_time: 6348.00305
# Current_accuracy : 92.022, Current_norm_ED  : 0.95
# Best_accuracy    : 92.096, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 환영하다                      | 환영하다                      | 0.9745	True
# 출입                        | 출입                        | 0.9540	True
# 피자                        | 쇠자                        | 0.9491	False
# 밤새우다                      | 밤새우다                      | 0.8312	True
# 넷째                        | 넷째                        | 1.0000	True
# --------------------------------------------------------------------------------
# [44000/300000] Train loss: 0.00004, Valid loss: 0.24309, Elapsed_time: 6649.30313
# Current_accuracy : 92.104, Current_norm_ED  : 0.95
# Best_accuracy    : 92.104, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 오다                        | 오다                        | 0.9998	True
# 실천하다                      | 실천하다                      | 0.9995	True
# 된                         | 된                         | 0.9998	True
# 대학원                       | 대학원                       | 1.0000	True
# 언어                        | 언어                        | 1.0000	True
# --------------------------------------------------------------------------------
# [46000/300000] Train loss: 0.00004, Valid loss: 0.24349, Elapsed_time: 6952.73388
# Current_accuracy : 92.029, Current_norm_ED  : 0.95
# Best_accuracy    : 92.104, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 발자국                       | 발자국                       | 0.9996	True
# 대전                        | 대전                        | 1.0000	True
# 연휴                        | 연휴                        | 0.9044	True
# 박스                        | 박스                        | 0.9998	True
# 암                         | 암                         | 1.0000	True
# --------------------------------------------------------------------------------
# [48000/300000] Train loss: 0.00004, Valid loss: 0.25010, Elapsed_time: 7246.76340
# Current_accuracy : 92.081, Current_norm_ED  : 0.95
# Best_accuracy    : 92.104, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 반발                        | 반발                        | 0.9997	True
# 가까워지다                     | 가까워지다                     | 0.5140	True
# 체                         | 체                         | 0.9961	True
# 싫어하다                      | 싫어하다                      | 0.9995	True
# 계란                        | 계란                        | 0.9927	True
# --------------------------------------------------------------------------------
# [50000/300000] Train loss: 0.00003, Valid loss: 0.24892, Elapsed_time: 7549.71771
# Current_accuracy : 92.096, Current_norm_ED  : 0.95
# Best_accuracy    : 92.104, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 습                         | 습                         | 0.9198	True
# 아까                        | 아까                        | 1.0000	True
# 투                         | 투                         | 1.0000	True
# 거대하다                      | 거대하다                      | 0.9995	True
# 천천히                       | 천천히                       | 0.9130	True
# --------------------------------------------------------------------------------
# [52000/300000] Train loss: 0.00003, Valid loss: 0.25649, Elapsed_time: 7854.27954
# Current_accuracy : 92.081, Current_norm_ED  : 0.95
# Best_accuracy    : 92.104, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 머물다                       | 머물다                       | 0.7430	True
# 개방되다                      | 설방되다                      | 0.4240	False
# 내려가다                      | 내려가다                      | 0.9998	True
# 조금씩                       | 조금씩                       | 0.6975	True
# 식당                        | 식당                        | 0.9999	True
# --------------------------------------------------------------------------------
# [54000/300000] Train loss: 0.00003, Valid loss: 0.24708, Elapsed_time: 8155.29237
# Current_accuracy : 92.081, Current_norm_ED  : 0.95
# Best_accuracy    : 92.104, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 수학                        | 수학                        | 0.9982	True
# 공간                        | 공간                        | 0.9979	True
# 싣                         | 싣                         | 0.5877	True
# 가지다                       | 가지다                       | 0.9990	True
# 장면                        | 장면                        | 0.9999	True
# --------------------------------------------------------------------------------
# [56000/300000] Train loss: 0.00003, Valid loss: 0.24820, Elapsed_time: 8456.59492
# Current_accuracy : 92.096, Current_norm_ED  : 0.95
# Best_accuracy    : 92.104, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 작품                        | 작물                        | 0.4962	False
# 덧                         | 덧                         | 0.9877	True
# 차마                        | 차마                        | 1.0000	True
# 자리                        | 자리                        | 0.9997	True
# 뛰어나오다                     | 뛰어나오다                     | 0.9060	True
# --------------------------------------------------------------------------------
# [58000/300000] Train loss: 0.00003, Valid loss: 0.25550, Elapsed_time: 8756.59025
# Current_accuracy : 92.118, Current_norm_ED  : 0.95
# Best_accuracy    : 92.118, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 슬쩍                        | 슬쩍                        | 0.9993	True
# 시도                        | 시도                        | 1.0000	True
# 바르다                       | 바르다                       | 0.9864	True
# 행운                        | 행운                        | 0.9995	True
# 판매하다                      | 판매하다                      | 0.9973	True
# --------------------------------------------------------------------------------
# [60000/300000] Train loss: 0.00003, Valid loss: 0.25820, Elapsed_time: 9059.84814
# Current_accuracy : 92.155, Current_norm_ED  : 0.95
# Best_accuracy    : 92.155, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 비행장                       | 비행장                       | 1.0000	True
# 알                         | 알                         | 1.0000	True
# 방송하다                      | 방송하다                      | 0.9968	True
# 피곤하다                      | 피곤하다                      | 1.0000	True
# 경제력                       | 간개                        | 0.0816	False
# --------------------------------------------------------------------------------
# [62000/300000] Train loss: 0.00003, Valid loss: 0.24978, Elapsed_time: 9360.04977
# Current_accuracy : 92.163, Current_norm_ED  : 0.95
# Best_accuracy    : 92.163, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 가능하다                      | 가능하다                      | 0.9984	True
# 실패                        | 실패                        | 0.9925	True
# 강도                        | 강도                        | 0.9998	True
# 의논                        | 의논                        | 1.0000	True
# 물건                        | 물건                        | 1.0000	True
# --------------------------------------------------------------------------------
# [64000/300000] Train loss: 0.00003, Valid loss: 0.24949, Elapsed_time: 9662.87160
# Current_accuracy : 92.155, Current_norm_ED  : 0.95
# Best_accuracy    : 92.163, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 달력                        | 달력                        | 0.9998	True
# 부인                        | 부인                        | 0.9888	True
# 죽                         | 국                         | 0.9843	False
# 그리                        | 조리                        | 0.8629	False
# 달러                        | 달러                        | 0.5047	True
# --------------------------------------------------------------------------------
# [66000/300000] Train loss: 0.00003, Valid loss: 0.25217, Elapsed_time: 9965.06112
# Current_accuracy : 92.148, Current_norm_ED  : 0.95
# Best_accuracy    : 92.163, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 스위치                       | 스위치                       | 0.9998	True
# 빼놓다                       | 빼놓다                       | 0.5639	True
# 가상                        | 가상                        | 0.9996	True
# 다듬다                       | 다듬다                       | 0.9928	True
# 수                         | 수                         | 0.9998	True
# --------------------------------------------------------------------------------
# [68000/300000] Train loss: 0.00002, Valid loss: 0.24919, Elapsed_time: 10270.48803
# Current_accuracy : 92.111, Current_norm_ED  : 0.95
# Best_accuracy    : 92.163, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 골고루                       | 골고루                       | 0.9993	True
# 청소년                       | 청소년                       | 0.9998	True
# 세워지다                      | 세워지다                      | 1.0000	True
# 낯설다                       | 낯설다                       | 0.9292	True
# 주문하다                      | 주문하다                      | 0.8964	True
# --------------------------------------------------------------------------------
# [70000/300000] Train loss: 0.00002, Valid loss: 0.24823, Elapsed_time: 10569.74479
# Current_accuracy : 92.096, Current_norm_ED  : 0.95
# Best_accuracy    : 92.163, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 쉽다                        | 쉽다                        | 0.9998	True
# 감기                        | 감기                        | 0.9996	True
# 제외되다                      | 제외되다                      | 0.6559	True
# 총                         | 총                         | 0.9999	True
# 베다                        | 베다                        | 1.0000	True
# --------------------------------------------------------------------------------
# [72000/300000] Train loss: 0.00002, Valid loss: 0.25425, Elapsed_time: 10870.68958
# Current_accuracy : 92.126, Current_norm_ED  : 0.95
# Best_accuracy    : 92.163, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 창조적                       | 창조적                       | 0.9983	True
# 양식                        | 양식                        | 0.9983	True
# 올여름                       | 올여름                       | 0.9992	True
# 가장                        | 가장                        | 0.9997	True
# 끌다                        | 끌다                        | 0.9998	True
# --------------------------------------------------------------------------------
# [74000/300000] Train loss: 0.00002, Valid loss: 0.25455, Elapsed_time: 11175.57111
# Current_accuracy : 92.155, Current_norm_ED  : 0.95
# Best_accuracy    : 92.163, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 그녀                        | 그녀                        | 0.9547	True
# 양                         | 양                         | 1.0000	True
# 젊                         | 젊                         | 0.9999	True
# 다시                        | 다시                        | 0.9969	True
# 불편하다                      | 불편하다                      | 0.9998	True
# --------------------------------------------------------------------------------
# [76000/300000] Train loss: 0.00002, Valid loss: 0.24797, Elapsed_time: 11477.60349
# Current_accuracy : 92.066, Current_norm_ED  : 0.95
# Best_accuracy    : 92.163, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 깨우다                       | 깨우다                       | 0.9933	True
# 종합                        | 종합                        | 0.7556	True
# 합격                        | 합격                        | 0.9999	True
# 겨우                        | 여우                        | 0.4593	False
# 주장하다                      | 주장하다                      | 0.9986	True
# --------------------------------------------------------------------------------
# [78000/300000] Train loss: 0.00002, Valid loss: 0.25824, Elapsed_time: 11779.77557
# Current_accuracy : 92.133, Current_norm_ED  : 0.95
# Best_accuracy    : 92.163, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 왼쪽                        | 왼쪽                        | 0.9961	True
# 옛날이야기                     | 옛날이야기                     | 0.9999	True
# 종                         | 총                         | 0.8329	False
# 며칠                        | 며칠                        | 0.8964	True
# 아이디어                      | 아이디어                      | 1.0000	True
# --------------------------------------------------------------------------------
# [80000/300000] Train loss: 0.00002, Valid loss: 0.25736, Elapsed_time: 12083.67598
# Current_accuracy : 92.155, Current_norm_ED  : 0.95
# Best_accuracy    : 92.163, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 느껴지다                      | 느껴지다                      | 1.0000	True
# 까먹다                       | 까먹다                       | 0.9996	True
# 찾아오다                      | 찾아오다                      | 0.8106	True
# 보다                        | 보다                        | 0.9352	True
# 서                         | 서                         | 0.9975	True
# --------------------------------------------------------------------------------
# [82000/300000] Train loss: 0.00002, Valid loss: 0.25606, Elapsed_time: 12387.59760
# Current_accuracy : 92.148, Current_norm_ED  : 0.95
# Best_accuracy    : 92.163, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 뒤집다                       | 뒤집다                       | 0.9998	True
# 계획                        | 계획                        | 0.8777	True
# 도                         | 도                         | 0.9994	True
# 싸구려                       | 싸구려                       | 0.9988	True
# 잔                         | 잔                         | 1.0000	True
# --------------------------------------------------------------------------------
# [84000/300000] Train loss: 0.00002, Valid loss: 0.25726, Elapsed_time: 12689.66503
# Current_accuracy : 92.096, Current_norm_ED  : 0.95
# Best_accuracy    : 92.163, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 거리                        | 거리                        | 0.8169	True
# 쏘다                        | 쏘다                        | 0.9401	True
# 열                         | 열                         | 1.0000	True
# 대회                        | 대회                        | 1.0000	True
# 팩                         | 팩                         | 1.0000	True
# --------------------------------------------------------------------------------
# [86000/300000] Train loss: 0.00002, Valid loss: 0.26107, Elapsed_time: 12992.12041
# Current_accuracy : 92.126, Current_norm_ED  : 0.95
# Best_accuracy    : 92.163, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 여우                        | 여우                        | 1.0000	True
# 걸리다                       | 걸리다                       | 0.9998	True
# 조각                        | 조각                        | 0.9529	True
# 숙제                        | 숙제                        | 0.4394	True
# 집단                        | 집단                        | 0.9969	True
# --------------------------------------------------------------------------------
# [88000/300000] Train loss: 0.00002, Valid loss: 0.25837, Elapsed_time: 13292.39896
# Current_accuracy : 92.141, Current_norm_ED  : 0.95
# Best_accuracy    : 92.163, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 딴                         | 딴                         | 1.0000	True
# 짝                         | 짝                         | 0.9929	True
# 다                         | 다                         | 0.9999	True
# 척                         | 첫                         | 0.8940	False
# 일반                        | 실반                        | 0.7445	False
# --------------------------------------------------------------------------------
# [90000/300000] Train loss: 0.00002, Valid loss: 0.25412, Elapsed_time: 13594.07902
# Current_accuracy : 92.118, Current_norm_ED  : 0.95
# Best_accuracy    : 92.163, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 방                         | 방                         | 0.9999	True
# 차                         | 차                         | 1.0000	True
# 통화                        | 통화                        | 0.9370	True
# 새롭다                       | 새롭다                       | 0.9996	True
# 고장                        | 고장                        | 1.0000	True
# --------------------------------------------------------------------------------
# [92000/300000] Train loss: 0.00002, Valid loss: 0.24936, Elapsed_time: 13896.85070
# Current_accuracy : 92.192, Current_norm_ED  : 0.95
# Best_accuracy    : 92.192, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 손님                        | 손님                        | 0.9995	True
# 되다                        | 되다                        | 0.5211	True
# 기술하다                      | 기슷하다                      | 0.4626	False
# 이하                        | 이하                        | 1.0000	True
# 탑                         | 탑                         | 0.9999	True
# --------------------------------------------------------------------------------
# [94000/300000] Train loss: 0.00002, Valid loss: 0.26038, Elapsed_time: 14200.71015
# Current_accuracy : 92.126, Current_norm_ED  : 0.95
# Best_accuracy    : 92.192, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 간장                        | 간장                        | 0.9975	True
# 민족                        | 민족                        | 1.0000	True
# 개방                        | 개방                        | 0.9978	True
# 설명되다                      | 설명되다                      | 0.9897	True
# 놔두다                       | 놔두다                       | 0.9808	True
# --------------------------------------------------------------------------------
# [96000/300000] Train loss: 0.00002, Valid loss: 0.25249, Elapsed_time: 14503.31044
# Current_accuracy : 92.178, Current_norm_ED  : 0.95
# Best_accuracy    : 92.192, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 요                         | 요                         | 0.9989	True
# 셈                         | 셈                         | 0.9196	True
# 당시                        | 당시                        | 0.9999	True
# 애초                        | 애초                        | 0.9995	True
# 톤                         | 톤                         | 0.9992	True
# --------------------------------------------------------------------------------
# [98000/300000] Train loss: 0.00002, Valid loss: 0.25310, Elapsed_time: 14803.84730
# Current_accuracy : 92.185, Current_norm_ED  : 0.95
# Best_accuracy    : 92.192, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 인사                        | 인사                        | 0.9151	True
# 외할머니                      | 외할머니                      | 0.9713	True
# 연말                        | 연말                        | 0.9828	True
# 식용유                       | 식용유                       | 0.9986	True
# 정확하다                      | 정확하다                      | 0.9116	True
# --------------------------------------------------------------------------------
# [100000/300000] Train loss: 0.00002, Valid loss: 0.25883, Elapsed_time: 15105.75721
# Current_accuracy : 92.192, Current_norm_ED  : 0.95
# Best_accuracy    : 92.192, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ...
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 보수                        | 보수                        | 0.9972	True
# 중반                        | 중반                        | 0.9859	True
# 마주                        | 마주                        | 0.8278	True
# 과거                        | 과거                        | 0.9819	True
# 꼬마                        | 모마                        | 0.4058	False
# --------------------------------------------------------------------------------
# [266000/300000] Train loss: 0.00001, Valid loss: 0.26294, Elapsed_time: 40210.97459
# Current_accuracy : 92.319, Current_norm_ED  : 0.95
# Best_accuracy    : 92.385, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 그야말로                      | 그야말로                      | 0.7392	True
# 산                         | 산                         | 0.9995	True
# 추진                        | 추진                        | 0.9743	True
# 날씨                        | 날씨                        | 0.9995	True
# 생산                        | 생산                        | 0.9801	True
# --------------------------------------------------------------------------------
# [268000/300000] Train loss: 0.00001, Valid loss: 0.27896, Elapsed_time: 40512.42599
# Current_accuracy : 92.356, Current_norm_ED  : 0.95
# Best_accuracy    : 92.385, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 팬                         | 팬                         | 1.0000	True
# 의류                        | 의류                        | 0.9992	True
# 아무렇다                      | 아무렇다                      | 1.0000	True
# 하긴                        | 하긴                        | 1.0000	True
# 밀리미터                      | 밀리미터                      | 0.9987	True
# --------------------------------------------------------------------------------
# [270000/300000] Train loss: 0.00001, Valid loss: 0.26167, Elapsed_time: 40812.99989
# Current_accuracy : 92.333, Current_norm_ED  : 0.95
# Best_accuracy    : 92.385, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 독일                        | 독일                        | 1.0000	True
# 소프트웨어                     | 소프트웨어                     | 0.9921	True
# 팬                         | 팬                         | 0.9997	True
# 약                         | 약                         | 0.9999	True
# 날                         | 날                         | 0.9991	True
# --------------------------------------------------------------------------------
# [272000/300000] Train loss: 0.00001, Valid loss: 0.27120, Elapsed_time: 41115.56748
# Current_accuracy : 92.326, Current_norm_ED  : 0.95
# Best_accuracy    : 92.385, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 끓                         | 물                         | 0.9727	False
# 끼다                        | 끼다                        | 0.9997	True
# 욕하다                       | 욕하다                       | 0.6616	True
# 구성되다                      | 구성되다                      | 1.0000	True
# 이날                        | 딸                         | 0.5727	False
# --------------------------------------------------------------------------------
# [274000/300000] Train loss: 0.00001, Valid loss: 0.26557, Elapsed_time: 41416.48485
# Current_accuracy : 92.333, Current_norm_ED  : 0.95
# Best_accuracy    : 92.385, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 그저                        | 그저                        | 1.0000	True
# 작아지다                      | 작아지다                      | 1.0000	True
# 대중적                       | 대중적                       | 1.0000	True
# 암시                        | 암시                        | 1.0000	True
# 빨리                        | 빨리                        | 0.9981	True
# --------------------------------------------------------------------------------
# [276000/300000] Train loss: 0.00001, Valid loss: 0.26341, Elapsed_time: 41714.78026
# Current_accuracy : 92.341, Current_norm_ED  : 0.95
# Best_accuracy    : 92.385, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 울리다                       | 올리다                       | 0.8116	False
# 끝내다                       | 끝내다                       | 0.9995	True
# 트럭                        | 트럭                        | 0.9999	True
# 세                         | 세                         | 1.0000	True
# 가리다                       | 가리다                       | 1.0000	True
# --------------------------------------------------------------------------------
# [278000/300000] Train loss: 0.00001, Valid loss: 0.26697, Elapsed_time: 42018.75405
# Current_accuracy : 92.311, Current_norm_ED  : 0.95
# Best_accuracy    : 92.385, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 다                         | 다                         | 1.0000	True
# 아                         | 아                         | 1.0000	True
# 정답                        | 정답                        | 0.9999	True
# 보람                        | 보람                        | 1.0000	True
# 평균                        | 평균                        | 0.9990	True
# --------------------------------------------------------------------------------
# [280000/300000] Train loss: 0.00001, Valid loss: 0.26602, Elapsed_time: 42321.40526
# Current_accuracy : 92.333, Current_norm_ED  : 0.95
# Best_accuracy    : 92.385, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 무더위                       | 무더위                       | 0.9996	True
# 무리                        | 무리                        | 0.4821	True
# 햄버거                       | 잃버거                       | 0.4666	False
# 정답                        | 절답                        | 0.6544	False
# 가다                        | 가다                        | 0.9999	True
# --------------------------------------------------------------------------------
# [282000/300000] Train loss: 0.00001, Valid loss: 0.27160, Elapsed_time: 42621.82503
# Current_accuracy : 92.348, Current_norm_ED  : 0.95
# Best_accuracy    : 92.385, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 멀리                        | 명리                        | 0.9854	False
# 경쟁력                       | 경쟁력                       | 0.9995	True
# 조                         | 조                         | 1.0000	True
# 안녕히                       | 안녕히                       | 0.9768	True
# 특이하다                      | 특이하다                      | 1.0000	True
# --------------------------------------------------------------------------------
# [284000/300000] Train loss: 0.00001, Valid loss: 0.25849, Elapsed_time: 42919.43946
# Current_accuracy : 92.348, Current_norm_ED  : 0.95
# Best_accuracy    : 92.385, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 섭씨                        | 섭씨                        | 0.9864	True
# 대전                        | 대전                        | 1.0000	True
# 아내                        | 아내                        | 1.0000	True
# 마사지                       | 마사지                       | 1.0000	True
# 엘                         | 엘                         | 0.9855	True
# --------------------------------------------------------------------------------
# [286000/300000] Train loss: 0.00001, Valid loss: 0.26734, Elapsed_time: 43222.02815
# Current_accuracy : 92.319, Current_norm_ED  : 0.95
# Best_accuracy    : 92.385, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 숨기다                       | 숨기다                       | 1.0000	True
# 작다                        | 작다                        | 1.0000	True
# 줍다                        | 줍다                        | 1.0000	True
# 모집하다                      | 모집하다                      | 0.7266	True
# 영어                        | 영어                        | 0.9132	True
# --------------------------------------------------------------------------------
# [288000/300000] Train loss: 0.00001, Valid loss: 0.26662, Elapsed_time: 43523.61682
# Current_accuracy : 92.370, Current_norm_ED  : 0.95
# Best_accuracy    : 92.385, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 예방하다                      | 예방하다                      | 0.4994	True
# 권                         | 권                         | 1.0000	True
# 반                         | 반                         | 0.9999	True
# 김                         | 기                         | 0.9007	False
# 매스컴                       | 매스컴                       | 1.0000	True
# --------------------------------------------------------------------------------
# [290000/300000] Train loss: 0.00001, Valid loss: 0.26378, Elapsed_time: 43827.55413
# Current_accuracy : 92.341, Current_norm_ED  : 0.95
# Best_accuracy    : 92.385, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 사위                        | 사위                        | 1.0000	True
# 그래                        | 그래                        | 0.9687	True
# 쌍                         | 쌍                         | 1.0000	True
# 적응                        | 적응                        | 1.0000	True
# 찌르다                       | 찌르다                       | 0.9978	True
# --------------------------------------------------------------------------------
# [292000/300000] Train loss: 0.00001, Valid loss: 0.25899, Elapsed_time: 44127.86689
# Current_accuracy : 92.356, Current_norm_ED  : 0.95
# Best_accuracy    : 92.385, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 편히                        | 편히                        | 0.9980	True
# 어리다                       | 어리다                       | 0.9999	True
# 쓰이다                       | 쓰이다                       | 0.9999	True
# 주전자                       | 주전자                       | 1.0000	True
# 아유                        | 아무                        | 0.5332	False
# --------------------------------------------------------------------------------
# [294000/300000] Train loss: 0.00001, Valid loss: 0.27046, Elapsed_time: 44431.59726
# Current_accuracy : 92.363, Current_norm_ED  : 0.95
# Best_accuracy    : 92.385, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 약혼녀                       | 약혼녀                       | 0.4269	True
# 일행                        | 일행                        | 1.0000	True
# 곧이어                       | 곧이어                       | 0.9975	True
# 달다                        | 달다                        | 1.0000	True
# 배고프다                      | 배고프다                      | 0.9999	True
# --------------------------------------------------------------------------------
# [296000/300000] Train loss: 0.00001, Valid loss: 0.27566, Elapsed_time: 44733.38944
# Current_accuracy : 92.393, Current_norm_ED  : 0.95
# Best_accuracy    : 92.393, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 겪                         | 겪                         | 0.8032	True
# 계산                        | 계산                        | 0.9990	True
# 시즌                        | 시즌                        | 1.0000	True
# 뒷산                        | 뒷산                        | 0.9843	True
# 형성되다                      | 형성되다                      | 0.9999	True
# --------------------------------------------------------------------------------
# [298000/300000] Train loss: 0.00001, Valid loss: 0.28071, Elapsed_time: 45035.47007
# Current_accuracy : 92.378, Current_norm_ED  : 0.95
# Best_accuracy    : 92.393, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 기대다                       | 기대다                       | 0.9999	True
# 이하                        | 이하                        | 0.9998	True
# 승부                        | 승부                        | 1.0000	True
# 뒤집다                       | 뒤집다                       | 1.0000	True
# 구월                        | 구월                        | 1.0000	True
# --------------------------------------------------------------------------------
# [300000/300000] Train loss: 0.00001, Valid loss: 0.27324, Elapsed_time: 45336.20207
# Current_accuracy : 92.370, Current_norm_ED  : 0.95
# Best_accuracy    : 92.393, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 평균                        | 평균                        | 0.9990	True
# 참                         | 참                         | 1.0000	True
# 식                         | 식                         | 1.0000	True
# 닫히다                       | 닫히다                       | 0.9932	True
# 걱정스럽다                     | 걱정스럽다                     | 0.6142	True
# --------------------------------------------------------------------------------
# end the training

# %% [markdown]
# 이런 방식으로 여러개의 모듈 조합을 테스트하고, 최종적으로 가장 좋은 모듈을 선택
#
# - Transformation : None, TPS
# - Feature Extraction : VGG, RCNN, BiLSTM
# - Sequence Modeling : None, BiLSTM
# - Prediction : Attn, CTC
